# %% [markdown]
# Checkpoint 1

# %%
urls = [
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-royal-challengers-bengaluru-1st-match-1422119/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-royal-challengers-bengaluru-1st-match-1422119/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-royal-challengers-bengaluru-1st-match-1422119/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/punjab-kings-vs-delhi-capitals-2nd-match-1422120/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/punjab-kings-vs-delhi-capitals-2nd-match-1422120/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/punjab-kings-vs-delhi-capitals-2nd-match-1422120/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-sunrisers-hyderabad-3rd-match-1422121/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-sunrisers-hyderabad-3rd-match-1422121/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/kolkata-knight-riders-vs-sunrisers-hyderabad-3rd-match-1422121/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-lucknow-super-giants-4th-match-1422122/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-lucknow-super-giants-4th-match-1422122/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-lucknow-super-giants-4th-match-1422122/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/gujarat-titans-vs-mumbai-indians-5th-match-1422123/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/gujarat-titans-vs-mumbai-indians-5th-match-1422123/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/gujarat-titans-vs-mumbai-indians-5th-match-1422123/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-punjab-kings-6th-match-1422124/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-punjab-kings-6th-match-1422124/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-punjab-kings-6th-match-1422124/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-gujarat-titans-7th-match-1422125/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-gujarat-titans-7th-match-1422125/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/chennai-super-kings-vs-gujarat-titans-7th-match-1422125/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/sunrisers-hyderabad-vs-mumbai-indians-8th-match-1422126/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/sunrisers-hyderabad-vs-mumbai-indians-8th-match-1422126/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/sunrisers-hyderabad-vs-mumbai-indians-8th-match-1422126/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-delhi-capitals-9th-match-1422127/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-delhi-capitals-9th-match-1422127/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/rajasthan-royals-vs-delhi-capitals-9th-match-1422127/ball-by-ball-commentary",
    ],
    [
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-kolkata-knight-riders-10th-match-1422128/full-scorecard",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-kolkata-knight-riders-10th-match-1422128/match-report",
        "https://www.espncricinfo.com/series/indian-premier-league-2024-1410320/royal-challengers-bengaluru-vs-kolkata-knight-riders-10th-match-1422128/ball-by-ball-",
    ],
]


import requests
from bs4 import BeautifulSoup


def download_and_save_html(url, filename):
    response = requests.get(url)
    soup = BeautifulSoup(response.content, "html.parser")

    with open(filename, "w", encoding="utf-8") as f:
        f.write(str(soup))  # Save the HTML content as a string


# Download and save HTML content for each match
for i in range(len(urls)):
    filename = f"scorecard_{i}.html"  # Customize filename format if needed
    download_and_save_html(urls[i][0], filename)

    filename = f"report_{i}.html"  # Customize filename format if needed
    download_and_save_html(urls[i][1], filename)

    filename = f"commentary_{i}.html"  # Customize filename format if needed
    download_and_save_html(urls[i][2], filename)

# %%
! mkdir html
! mv *.html html/
# Out:
# mkdir: cannot create directory 'html': File exists

# %% [markdown]
# GEMINI

# %%
# !pip install -q langchain sentence-transformers langchain-chroma unstructured
# !pip install -q accelerate==0.21.0 \
#                 peft==0.4.0 \
#                 bitsandbytes==0.40.2 \
#                 trl==0.4.7
# !pip install -q lxml

# %% [markdown]
# # Without Chunk

# %%
# from langchain_community.document_loaders import BSHTMLLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import BSHTMLLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)

from langchain_community.document_loaders import (
    UnstructuredHTMLLoader,
    BSHTMLLoader,
    DirectoryLoader,
)


embeddings = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

data_dir = "./html/"

loaded_data = []


loader = DirectoryLoader(
    path="./html/", glob="*.html", loader_cls=BSHTMLLoader
)
docs = loader.load()


# text_splitter = RecursiveCharacterTextSplitter(
#     chunk_size=1024,
#     chunk_overlap=64,
# )

# texts_chunks = text_splitter.split_documents(*loaded_data)


db = Chroma.from_documents(docs, embeddings, persist_directory="./ipl_db")


# # Test Similarity Search
# query = "How did Shivam Dube overcome his initial struggles against the short ball and contribute to CSK's victory?"
# docs = db.similarity_search(query)

# print(docs[0].page_content)

# %% [markdown]
# # With Chunking

# %%
# from langchain_community.document_loaders import BSHTMLLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import BSHTMLLoader
from langchain_community.vectorstores import Chroma
from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)

from langchain_community.document_loaders import (
    UnstructuredHTMLLoader,
    BSHTMLLoader,
    DirectoryLoader,
)


embeddings = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

data_dir = "./html/"

loaded_data = []

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1000,
    chunk_overlap=200,
)

loader = DirectoryLoader(
    path="./html/", glob="*.html", loader_cls=BSHTMLLoader
)
docs = loader.load_and_split(text_splitter)


db = Chroma.from_documents(docs, embeddings, persist_directory="./ipl2_db")

# %% [markdown]
# # maybe

# %%
import os
import torch
from transformers import (
  AutoTokenizer,
  AutoModelForCausalLM,
  BitsAndBytesConfig,
  pipeline
)

from transformers import BitsAndBytesConfig

from langchain.text_splitter import CharacterTextSplitter

from langchain.embeddings.huggingface import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

from langchain.prompts import PromptTemplate
from langchain.schema.runnable import RunnablePassthrough
from langchain.llms import HuggingFacePipeline
from langchain.chains import LLMChain
import transformers
import nest_asyncio

nest_asyncio.apply()
from tqdm.notebook import tqdm
from langchain_community.document_loaders import PyPDFLoader

# %%
from huggingface_hub import login
login(token="your hugging faces user access token here") # :)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: read).
# Your token has been saved to /home/studio-lab-user/.cache/huggingface/token
# Login successful

# %%
# Load Tokenizer
model_name='mistralai/Mistral-7B-Instruct-v0.2'

tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "right"
print("Tokenizer loaded !!")
## bitsandbytes parameters
# Activate 4-bit precision base model loading
use_4bit = True

# Compute dtype for 4-bit base models
bnb_4bit_compute_dtype = "float16"

# Quantization type (fp4 or nf4)
bnb_4bit_quant_type = "nf4"

# Activate nested quantization for 4-bit base models (double quantization)
use_nested_quant = False

compute_dtype = getattr(torch, bnb_4bit_compute_dtype)

bnb_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type=bnb_4bit_quant_type,
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=use_nested_quant,
)

# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)
# Load Model
model = AutoModelForCausalLM.from_pretrained(
        model_name,
            quantization_config=bnb_config,
        )
# Out:
# /home/studio-lab-user/.conda/envs/default/lib/python3.9/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# `low_cpu_mem_usage` was None, now set to True since model is quantized.
# Tokenizer loaded !!
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# You are calling `save_pretrained` to a 4-bit converted model, but your `bitsandbytes` version doesn't support it. If you want to save 4-bit models, make sure to have `bitsandbytes>=0.41.3` installed.

# %%
# # Testing Vanilla Model

# def get_vanilla_response(question, tokenizer, model):
#   inputs = tokenizer.encode_plus(f"[INST] {question} [/INST]", return_tensors="pt")['input_ids'].to('cuda')

#   generated_ids = model.generate(inputs,
#                                 max_new_tokens=1000,
#                                 do_sample=True)
#   output = tokenizer.batch_decode(generated_ids)
#   return output[0]

# question = "What changes do I need in my personality to make friends easily?"
# print(get_vanilla_response(question = question, tokenizer = tokenizer, model = model))

# %%
def temp(inp):
    return inp[inp.find('Answer'):]

# %%
from langchain_core.output_parsers import StrOutputParser


# Create a text generation pipeline
text_generation_pipeline = pipeline(
    model=model,
    tokenizer=tokenizer,
    task="text-generation",
    # temperature=0.2,
    repetition_penalty=1.1,
    return_full_text=True,
    max_new_tokens=10000,
)

mistral_llm = HuggingFacePipeline(pipeline=text_generation_pipeline)

retriever = db.as_retriever()
# Create prompt template
prompt_template = """
You are an assistant for question-answering tasks. Use the following pieces of retrieved context to answer the question. If you don't know the answer, just say that you don't know.

Context: {context}

Question: {question} 

Answer:
 """

# Create prompt from prompt template
prompt = PromptTemplate(
    input_variables=["context", "question"],
    template=prompt_template,
)

# Create llm chain
# llm_chain = LLMChain(llm=mistral_llm, prompt=prompt)

rag_chain = (
 {"context": retriever, "question": RunnablePassthrough()}
    | prompt | mistral_llm | temp
)

# %%
# testing on the same question for a comparison
question = "how many runs did RCB score in RCB vs CSK match?"
rag_chain.invoke(question)
# Out:
# 'Answer:\n  RCB scored 173 runs in RCB vs CSK match.'

# %%
# testing on the same question for a comparison
question = "Who is the RR captain?"
rag_chain.invoke(question)
# Out:
# Answer:
#
# Sanju Samson is the RR captain.

# %%
match_questions = {
    "RCB vs CSK": [
        "How did CSK's bowling strategy in the powerplay contribute to their success against RCB's top order?",
        "Despite losing wickets, how did RCB manage to post a competitive total of 173 runs?",
        "What was the turning point of CSK's chase after Rachin Ravindra's quick start?",
        "How did Shivam Dube overcome his initial struggles against the short ball and contribute to CSK's victory?",
        "What key factors differentiated the performance of the two teams and led to CSK's win?"
    ],
    "DC vs PBKS": [
        "How did the impact player substitutions affect the strategies and outcomes for both teams?",
        "Do you think Ishant Sharma's injury significantly hampered Delhi Capitals' ability to defend their total?",
        "How did Sam Curran's innings change the course of the match for Punjab Kings?",
        "Despite taking two key wickets, why was Kuldeep Yadav unable to restrict Punjab Kings from achieving the target?",
        "What were the key tactical errors made by Delhi Capitals that contributed to their defeat?"
    ],
    "KKR vs SRH": [
        "How did Andre Russell's performance with both bat and ball contribute to KKR's victory?",
        "Despite a strong start, why did the Sunrisers Hyderabad middle order struggle to maintain the required run rate?",
        "How did Sunil Narine's economical bowling spell impact the course of the match?",
        "Do you think KKR's decision to send Sunil Narine to open the batting was justified?",
        "How did Harshit Rana's final over bowling performance demonstrate his composure and ability to handle pressure?"
    ],
    "RR vs LSG": [
        "How did Sanju Samson's leadership and batting performance influence the outcome of the match for Rajasthan Royals?",
        "Despite a poor start, how did KL Rahul and Nicholas Pooran bring Lucknow Super Giants back into contention?",
        "What was the turning point of the match after LSG's recovery during the middle overs?",
        "How did Trent Boult's early wickets set the tone for Rajasthan Royals' bowling performance?",
        "Do you think LSG's decision to use Deepak Hooda as the impact player was effective?"
    ],
    "GT vs MI": [
        "How did Gujarat Titans' bowlers manage to restrict Mumbai Indians' strong batting lineup and secure a victory despite a seemingly low total?",
        "Do you think Jasprit Bumrah's bowling performance was underutilized by Mumbai Indians, given his effectiveness and economical figures?",
        "What role did Sai Sudharsan play in anchoring Gujarat Titans' innings and building a defendable total?",
        "How did the pitch conditions and the use of slower balls contribute to the bowlers' success in this match?",
        "In hindsight, do you think Mumbai Indians made any tactical errors in their batting approach during the middle overs?"
    ],
    "PBKS vs RCB": [
        "How did Virat Kohli's aggressive start to the chase impact the momentum of the match for RCB?",
        "What were the key factors behind Harpreet Brar's successful bowling spell that restricted RCB's scoring rate?",
        "How did the impact player substitutions influence the strategies and outcomes for both teams?",
        "Despite Kohli's impressive innings, why did RCB find themselves in a precarious situation towards the end of the chase?",
        "How did Dinesh Karthik's composure and finishing skills contribute to RCB's victory in a tense final over?"
    ],
    "CSK vs GT": [
        "How did Rachin Ravindra and Shivam Dube's aggressive batting contributions set the foundation for CSK's imposing total?",
        "What were the key factors behind the success of CSK's fast bowlers, particularly Deepak Chahar and Tushar Deshpande, in restricting Gujarat Titans' run chase?",
        "How did CSK's fielding performance, including several outstanding catches, contribute to their dominant victory?",
        "Despite their success in the previous match, why did Gujarat Titans' spinners, Rashid Khan and Sai Kishore, struggle to contain CSK's batsmen?",
        "Do you think the impact player substitutions made by both teams had a significant influence on the outcome of the match?"
    ],
    "SRH vs MI": [
        "How did the early life given to Travis Head by Tim David impact the course of the match and SRH's final total?",
        "What were the key differences in the batting approaches of Travis Head and Abhishek Sharma during the powerplay, and how did they both contribute to SRH's explosive start?",
        "Despite taking the wicket of Abhishek Sharma, why was Piyush Chawla expensive in his bowling spell, and how did this affect MI's chances of restricting SRH?",
        "Do you think Mumbai Indians' decision to promote Naman Dhir to number 3 was justified, considering his limited T20 experience?",
        "How did Sunrisers Hyderabad's bowlers manage to defend a high total and secure victory despite the onslaught from Mumbai Indians' batsmen?"
    ],
    "RR vs DC": [
        "How did the early seam movement exploited by Delhi Capitals' bowlers impact Rajasthan Royals' batting strategy and early scoring rate?",
        "What was the rationale behind promoting Ravichandran Ashwin in the batting order, and how did his innings contribute to Rajasthan Royals' total?",
        "How did Riyan Parag's innings demonstrate his ability to adapt to challenging conditions and accelerate the scoring rate during the latter stages of the innings?",
        "Why were Delhi Capitals unable to capitalize on the improved batting conditions and chase down the target despite a strong start from David Warner?",
        "How did the bowling performances of Nandre Burger and Yuzvendra Chahal restrict Delhi Capitals' scoring and contribute to Rajasthan Royals' victory?"
    ],
    "KKR vs RCB": [
        "How did Sunil Narine's performance in his 500th T20 match reflect his enduring value and impact on KKR's success?",
        "Despite Virat Kohli's impressive unbeaten innings of 83, why did RCB's middle-order struggle to accelerate the scoring rate and post a more challenging total?",
        "What were the key tactical decisions made by KKR, such as the use of Sunil Narine as an opener and the impact player substitutions, that contributed to their victory?",
        "How did KKR's bowlers, particularly Andre Russell and Harshit Rana, utilize slower balls and variations in pace to disrupt RCB's batting rhythm and take crucial wickets?",
        "What does KKR's victory over RCB, the first away team win of the season, suggest about the potential shift in the balance between home and away teams in IPL 2024?"
    ]
}

# %%
for key,value in match_questions.items():
    question = f"For the match {key}, answer the following questions:\n\n"
    for i in range(5):
        question += f"{i+1}. {value[i]}\n"
    ans = rag_chain.invoke(question)
    with open(f"ans/{key}.txt", "w") as f:
        f.write(ans)
    print('done with', key)
# Out:
# done with RCB vs CSK
# done with DC vs PBKS
# done with KKR vs SRH
# done with RR vs LSG
# done with GT vs MI
# done with PBKS vs RCB
# done with CSK vs GT
# done with SRH vs MI
# You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
# done with RR vs DC
# done with KKR vs RCB

# %%
# # Test Similarity Search
query = "KKR"
docs = db.similarity_search(query)

print(docs[0].page_content)
# Out:
# for 6 (Kohli 83*, Russell 2-29, Rana 2-39) by seven wicketsIt took 10 matches for IPL 2024 to produce a victory by the away team. Though it was perhaps predictable that it came at the M Chinnaswamy stadium, where the small ground really does favour the chasing team. That, on Friday, was Kolkata Knight Riders, who overcame a Virat Kohli masterclass to chase down 183 and claim the two points.Narine stars in 500th gameKKR's opening partnership had been a problem area in recent years. But they won this game with it. They had to score a lot of their target inside the first six overs, not just because of the field restrictions, but because that's when the ball is hard and new and that's when it comes onto the bat. RCB's innings already showed that as it got softer and older, going into the wicket and taking pace off became mighty effective. Andre Russell (2-29) and Harshit Rana (2-39) used it to good effect.This, though, is the KKR gameplan regardless of the venue they're playing at becaus
# ...

# %%
print(docs)
# Out:
# [Document(page_content="for 6 (Kohli 83*, Russell 2-29, Rana 2-39) by seven wicketsIt took 10 matches for IPL 2024 to produce a victory by the away team. Though it was perhaps predictable that it came at the M Chinnaswamy stadium, where the small ground really does favour the chasing team. That, on Friday, was Kolkata Knight Riders, who overcame a Virat Kohli masterclass to chase down 183 and claim the two points.Narine stars in 500th gameKKR's opening partnership had been a problem area in recent years. But they won this game with it. They had to score a lot of their target inside the first six overs, not just because of the field restrictions, but because that's when the ball is hard and new and that's when it comes onto the bat. RCB's innings already showed that as it got softer and older, going into the wicket and taking pace off became mighty effective. Andre Russell (2-29) and Harshit Rana (2-39) used it to good effect.This, though, is the KKR gameplan regardless of the venue t
# ...

# %% [markdown]
# # Advanced RAG

# %% [markdown]
# ### Parent Child Splitter

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.document_loaders import BSHTMLLoader
from langchain_community.vectorstores import Chroma
from langchain.storage import InMemoryStore
from langchain.retrievers import ParentDocumentRetriever

from langchain_community.embeddings.sentence_transformer import (
    SentenceTransformerEmbeddings,
)

from langchain_community.document_loaders import (
    UnstructuredHTMLLoader,
    BSHTMLLoader,
    DirectoryLoader,
)


embeddings = SentenceTransformerEmbeddings(model_name="all-mpnet-base-v2")

data_dir = "./html/"


parent_splitter = RecursiveCharacterTextSplitter(chunk_size=2000)

child_splitter = RecursiveCharacterTextSplitter(chunk_size=400)

vectorstore = Chroma(
    collection_name="ipl_pc_db", embedding_function=embeddings
)

# The storage layer for the parent documents
store = InMemoryStore()

retriever = ParentDocumentRetriever(
    vectorstore=vectorstore,
    docstore=store,
    child_splitter=child_splitter,
    parent_splitter=parent_splitter
)

loader = DirectoryLoader(
    path="./html/", glob="*.html", loader_cls=BSHTMLLoader
)
docs = loader.load_and_split(text_splitter)
retriever.add_documents(docs)


# db = Chroma.from_documents(docs, embeddings, persist_directory="./ipl_pc_db")

# %%
len(list(store.yield_keys()))
# Out:
# 433

# %% [markdown]
# # Re Ranking

# %%
# !pip install --upgrade --quiet  cohere langchain_cohere

# %%
# get a new token: https://dashboard.cohere.ai/

import getpass
import os

os.environ["COHERE_API_KEY"] = getpass.getpass("Cohere API Key:")
# Out:
# Cohere API Key: ········

# %%
# Helper function for printing docs


def pretty_print_docs(docs):
    print(
        f"\n{'-' * 100}\n".join(
            [f"Document {i+1}:\n\n" + d.page_content for i, d in enumerate(docs)]
        )
    )

# %%
from langchain.retrievers.contextual_compression import ContextualCompressionRetriever
from langchain_cohere import CohereRerank
from langchain_community.llms import Cohere

llm = Cohere(temperature=0)
compressor = CohereRerank()
compression_retriever = ContextualCompressionRetriever(
    base_compressor=compressor, base_retriever=retriever
)

rag_chain = (
 {"context": compression_retriever, "question": RunnablePassthrough()}
    | prompt | mistral_llm | temp
)

# %%
rag_chain.invoke("How did CSK's bowling strategy in the powerplay contribute to their success against RCB's top order?")
# Out:
# "Answer:\n  In the powerplay, CSK employed a bowling strategy that focused on using the two-bouncer rule effectively. This strategy kept the RCB batsmen on their toes and prevented them from settling into their innings. Deepak Chahar, who bowled three powerplay overs, mentioned that this approach helped keep the batters guessing and expecting the second bouncer. This strategy paid off as RCB lost key batsmen like Virat Kohli and Faf du Plessis cheaply, which put pressure on their middle order. Additionally, Ravindra Jadeja and Dwayne Bravo were able to pick up crucial wickets towards the end of the innings, further limiting RCB's scoring capacity. Overall, CSK's bowling strategy in the powerplay played a significant role in restricting RCB's top order and setting the tone for their eventual victory."
